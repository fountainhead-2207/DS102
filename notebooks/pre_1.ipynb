# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
gr_dir = r'/home/check/DATA/university/yr3, hk1/DS102 - ML for Statistic/Đồ án/goodread/DS102/DATA/bronze/GOODREADS/'
nyt_dir = r'/home/check/DATA/university/yr3, hk1/DS102 - ML for Statistic/Đồ án/goodread/DS102/DATA/bronze/NYT/'
root_dir = r'/home/check/DATA/university/yr3, hk1/DS102 - ML for Statistic/Đồ án/goodread/DS102/'

# %%
def normalize_name(name):
    if pd.isna(name):
        return ''
    name = str(name)
    name = name.lower()
    name = ' '.join(name.split())
    name = name.replace('.', '')
    name = ''.join(c for c in name if c.isalnum() or c.isspace())
    return name.strip()

# %%
import pandas as pd
from rapidfuzz import process, fuzz

def fuzzy_merge(df1, df2, key1, key2, threshold=90):

    choices = df2[key2].dropna().astype(str).unique()
    choices_list = choices.tolist()

    def find_best_match(name):
        if pd.isna(name):
            return None, 0
        name = str(name)
        match = process.extractOne(name, choices_list, scorer=fuzz.ratio)
        if match and match[1] >= threshold:
            return match[0]  
        return None

    df1 = df1.copy()
    df1['_matched_key'] = df1[key1].apply(lambda x: find_best_match(x))


    df1_matched = df1.dropna(subset=['_matched_key'])

    result = df1_matched.merge(
        df2,
        left_on='_matched_key',
        right_on=key2,
        how='inner',
        suffixes=('_left', '_right')
    )

    result = result.drop(columns=['_matched_key'])
    return result

# %% [markdown]
# ## Goodreads
#
# **Ref:**
# https://cseweb.ucsd.edu/~jmcauley/datasets/goodreads.html#datasets

# %% [markdown]
# ### goodreads_books

# %%
goodreads_books_cols = [
    'book_id',            
    'title',                 
    'author',              
    'publication_year',     
    'average_rating',        
    'ratings_count',        
    'description',          
]
gr_books_df = pd.read_parquet(gr_dir + 'goodreads_books.parquet', 
                              engine='fastparquet', columns=goodreads_books_cols)

# %%
print(gr_books_df.columns)
gr_books_df.head()
# Out:
# Index(['book_id', 'title', 'author', 'publication_year', 'average_rating',
#        'ratings_count', 'description'],
#       dtype='object')
#    book_id                                              title  \
# 0  5333265                        W.C. Fields: A Life on Film
# 1  1333909                                        Good Harbor
# 2  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3  6066819                               Best Friends Forever
# 4   287140  Runic Astrology: Starcraft and Timekeeping in ...
#
#              author publication_year average_rating ratings_count  \
# 0  Ronald J. Fields             1984           4.00             3
# 1     Anita Diamant             2001           3.23            10
# 2    Barbara Hambly             1987           4.03           140
# 3   Jennifer Weiner             2009           3.49         51184
# 4     Nigel Pennick                            3.40            15
#
#                                          description
# 0
# 1  Anita Diamant's international bestseller "The ...
# 2  Omnibus book club edition containing the Ladie...
# 3  Addie Downs and Valerie Adler were eight when ...
# 4

# %%
print(gr_books_df.isna().sum(),'\n')
print(gr_books_df.shape,'\n')
# Out:
# book_id               0
# title                 0
# author              537
# publication_year      0
# average_rating        0
# ratings_count         0
# description           0
# dtype: int64
#
# (2360655, 7)

# %%
gr_books_df.dropna(axis=0,how='any',inplace=True)

# %%
gr_books_df.dtypes
# Out:
# book_id             object
# title               object
# author              object
# publication_year    object
# average_rating      object
# ratings_count       object
# description         object
# dtype: object

# %%
gr_books_df['publication_year'] = pd.to_numeric(gr_books_df['publication_year'], errors='coerce').astype('Int64')
gr_books_df['average_rating'] = pd.to_numeric(gr_books_df['average_rating'], errors='coerce').astype('float64')
gr_books_df['ratings_count'] = pd.to_numeric(gr_books_df['ratings_count'], errors='coerce').astype('int64')

# %% [markdown]
# ### goodreads_reviews

# %%
goodreads_reviews_cols = [
    'book_id',              
    'rating',               
    'review_text',           
    'n_votes',              
    'date_added',             
]
gr_reviews_df = pd.read_parquet(gr_dir + 'goodreads_reviews_dedup.parquet',
                                 engine='fastparquet',
                                 columns=goodreads_reviews_cols)

# %%
print(gr_reviews_df.columns)
gr_reviews_df.head()
# Out:
# Index(['book_id', 'rating', 'review_text', 'n_votes', 'date_added'], dtype='object')
#     book_id  rating                                        review_text  \
# 0  24375664       5  Mind blowingly cool. Best science fiction I've...
# 1  18245960       5  This is a special book. It started slow for ab...
# 2   6392944       3  I haven't read a fun mystery book in a while a...
# 3  22078596       4  Fun, fast paced, and disturbing tale of murder...
# 4   6644782       4  A fun book that gives you a sense of living in...
#
#    n_votes                      date_added
# 0       16  Fri Aug 25 13:55:02 -0700 2017
# 1       28  Sun Jul 30 07:44:10 -0700 2017
# 2        6  Mon Jul 24 02:48:17 -0700 2017
# 3       22  Mon Jul 24 02:33:09 -0700 2017
# 4        8  Mon Jul 24 02:28:14 -0700 2017

# %%
print(gr_reviews_df.isna().sum())
print(gr_reviews_df.shape)
# Out:
# book_id        0
# rating         0
# review_text    0
# n_votes        0
# date_added     0
# dtype: int64
# (15739967, 5)

# %% [markdown]
# ### merge goodread

# %%
gr = gr_books_df.merge(gr_reviews_df,on='book_id',how='left')

# %%
gr.head()
# Out:
#    book_id                                              title  \
# 0  5333265                        W.C. Fields: A Life on Film
# 1  1333909                                        Good Harbor
# 2  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 4  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...
#
#              author  publication_year  average_rating  ratings_count  \
# 0  Ronald J. Fields              1984            4.00              3
# 1     Anita Diamant              2001            3.23             10
# 2    Barbara Hambly              1987            4.03            140
# 3    Barbara Hambly              1987            4.03            140
# 4    Barbara Hambly              1987            4.03            140
#
#                                          description  rating  \
# 0                                                        4.0
# 1  Anita Diamant's international bestseller "The ...     2.0
# 2  Omnibus book club edition containing the Ladie...     3.0
# 3  Omnibus book club edition containing the Ladie...     4.0
# 4  Omnibus book club edition containing the Ladie...     3.0
#
#                                          review_text  n_votes  \
# 0  Loved this book about WC Fields written by his...      1.0
# 1  Not much I can say that many reviewers haven't...      0.0
# 2  Competent. I'm sure I read the first half year...      1.0
# 3  While these books are excellent overall, I thi...      0.0
# 4  A collection of two novels about the mercenary...      0.0
#
#                        date_added
# 0  Sun Jun 19 12:09:45 -0700 2016
# 1  Wed Apr 04 07:47:34 -0700 2012
# 2  Fri Dec 18 14:06:12 -0800 2009
# 3  Tue Apr 04 07:18:36 -0700 2017
# 4  Fri Oct 11 10:08:07 -0700 2013

# %%
gr.isna().sum()
# Out:
# book_id                   0
# title                     0
# author                    0
# publication_year    2703801
# average_rating            0
# ratings_count             0
# description               0
# rating               280209
# review_text          280209
# n_votes              280209
# date_added           280209
# dtype: int64

# %%
gr.dropna(subset=['rating','publication_year'],axis=0, inplace=True)

# %%
gr.isna().sum()
# Out:
# book_id             0
# title               0
# author              0
# publication_year    0
# average_rating      0
# ratings_count       0
# description         0
# rating              0
# review_text         0
# n_votes             0
# date_added          0
# dtype: int64

# %%
gr.shape
# Out:
# (13134415, 11)

# %% [markdown]
# ## Books sales and ratings
#
# **Ref:** https://www.kaggle.com/datasets/thedevastator/books-sales-and-ratings

# %% [markdown]
# ### Sale_data

# %%
books_sale_cols = [
    'Book Name',             
    'Author',                 
    'genre',                 
    'gross sales',         
    'publisher revenue',    
    'sale price',           
    'sales rank',            
    'units sold',            
    'Author_Rating',             
]
sale_df = pd.read_csv(root_dir + 'DATA/bronze/Books_Sale.csv',usecols=books_sale_cols)

# %%
sale_df.head()
# Out:
#                          Book Name  \
# 0                          Beowulf
# 1                 Batman: Year One
# 2                Go Set a Watchman
# 3  When You Are Engulfed in Flames
# 4         Daughter of Smoke & Bone
#
#                                               Author Author_Rating  \
# 0                             Unknown, Seamus Heaney        Novice
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                         Harper Lee        Novice
# 3                                      David Sedaris  Intermediate
# 4                                       Laini Taylor  Intermediate
#
#            genre  gross sales  publisher revenue  sale price  sales rank  \
# 0  genre fiction      34160.0            20496.0        4.88           1
# 1  genre fiction      12437.5             7462.5        1.99           2
# 2  genre fiction      47795.0            28677.0        8.69           3
# 3        fiction      41250.0            24750.0        7.50           3
# 4  genre fiction      37952.5            22771.5        7.99           4
#
#    units sold
# 0        7000
# 1        6250
# 2        5500
# 3        5500
# 4        4750

# %%
print(sale_df[(sale_df['gross sales'] - sale_df['units sold'] < 0) & (sale_df['sale price'] > 1)][['Book Name','gross sales','units sold','sale price']])
# Out:
#                                         Book Name  gross sales  units sold  \
# 356                                As I Lay Dying       461.68        6264
# 357                  Harold and the Purple Crayon       925.68        6264
# 358  Lover Eternal (Black Dagger Brotherhood, #2)      2460.15        6237
# 359                                           NaN       690.69        6237
# 360                                    Fool Moon        687.70        6210
# ..                                            ...          ...         ...
# 976                The Power of Positive Thinking       325.91        4240
# 978                            The House of Mirth       325.91        4240
# 979                                  Fairy Tail 1       434.91        4240
# 980              The Slow Regard of Silent Things       434.91        4240
# 981                          Twelve Years a Slave       543.91        4240
#
#      sale price
# 356        1.99
# 357        3.99
# 358       10.65
# 359        2.99
# 360        2.99
# ..          ...
# 976        2.99
# 978        2.99
# 979        3.99
# 980        3.99
# 981        4.99
#
# [506 rows x 4 columns]

# %%
sale_cols = sale_df.columns
s_new_cols = []
for col in sale_cols:
    proper_col = col.title()
    proper_col = proper_col.replace(' ', '_')
    s_new_cols.append(proper_col)

sale_df.columns = s_new_cols

# %%
sale_df.dtypes
# Out:
# Book_Name             object
# Author                object
# Author_Rating         object
# Genre                 object
# Gross_Sales          float64
# Publisher_Revenue    float64
# Sale_Price           float64
# Sales_Rank             int64
# Units_Sold             int64
# dtype: object

# %%
sale_df.head()
# Out:
#                          Book_Name  \
# 0                          Beowulf
# 1                 Batman: Year One
# 2                Go Set a Watchman
# 3  When You Are Engulfed in Flames
# 4         Daughter of Smoke & Bone
#
#                                               Author Author_Rating  \
# 0                             Unknown, Seamus Heaney        Novice
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                         Harper Lee        Novice
# 3                                      David Sedaris  Intermediate
# 4                                       Laini Taylor  Intermediate
#
#            Genre  Gross_Sales  Publisher_Revenue  Sale_Price  Sales_Rank  \
# 0  genre fiction      34160.0            20496.0        4.88           1
# 1  genre fiction      12437.5             7462.5        1.99           2
# 2  genre fiction      47795.0            28677.0        8.69           3
# 3        fiction      41250.0            24750.0        7.50           3
# 4  genre fiction      37952.5            22771.5        7.99           4
#
#    Units_Sold
# 0        7000
# 1        6250
# 2        5500
# 3        5500
# 4        4750

# %%
sale_df['Book_Name'] = sale_df['Book_Name'].str.title()

# %% [markdown]
# ## New York Times BestSellers
#
# **Ref:** https://www.kaggle.com/datasets/sujaykapadnis/new-york-times-bestsellers

# %% [markdown]
# ### nyt_titles

# %%
nyt_titles_cols = [           
    'title',           
    'author',         
    'year',           
    'total_weeks',   
    'first_week',      
    'debut_rank',     
    'best_rank'     
]
nyt_titles_df = pd.read_csv(nyt_dir + 'nyt_titles.tsv',sep='\t',usecols=nyt_titles_cols)

# %%
nyt_titles_df.head()
# Out:
#                   title                author  year  total_weeks  first_week  \
# 0   "H" IS FOR HOMICIDE           Sue Grafton  1991           15  1991-05-05
# 1   "I" IS FOR INNOCENT           Sue Grafton  1992           11  1992-04-26
# 2  ''G'' IS FOR GUMSHOE           Sue Grafton  1990            6  1990-05-06
# 3       A DOG'S JOURNEY      W. Bruce Cameron  2012            1  2012-05-27
# 4        CHANGING FACES  Kimberla Lawson Roby  2006            1  2006-02-19
#
#    debut_rank  best_rank
# 0           1          2
# 1          14          2
# 2           4          8
# 3           3         14
# 4          11         14

# %%
nyt_titles_df['title']=nyt_titles_df['title'].str.title()

# %%
nyt_titles_df.shape
# Out:
# (7431, 7)

# %% [markdown]
# ### nyt_full

# %%
nyt_full_cols = [
    'title',  
    'year',
    'week',
    'rank'       
]

nyt_full_df = pd.read_csv(nyt_dir + 'nyt_full.tsv',sep='\t',usecols=nyt_full_cols)

# %%
nyt_full_df.head()
# Out:
#    year        week  rank                      title
# 0  1931  1931-10-12     1       THE TEN COMMANDMENTS
# 1  1931  1931-10-12     2           FINCHE'S FORTUNE
# 2  1931  1931-10-12     3             THE GOOD EARTH
# 3  1931  1931-10-12     4        SHADOWS ON THE ROCK
# 4  1931  1931-10-12     5  SCARMOUCHE THE KING MAKER

# %%
nyt_full_df['title'] = nyt_full_df['title'].str.title()

# %%
nyt_full_df.head()
# Out:
#    year        week  rank                      title
# 0  1931  1931-10-12     1       The Ten Commandments
# 1  1931  1931-10-12     2           Finche'S Fortune
# 2  1931  1931-10-12     3             The Good Earth
# 3  1931  1931-10-12     4        Shadows On The Rock
# 4  1931  1931-10-12     5  Scarmouche The King Maker

# %%
nyt_full_df.shape
# Out:
# (60386, 4)

# %%
nyt_df = nyt_titles_df.merge(nyt_full_df, on='title',how='left')

# %%
nyt_df.head()
# Out:
#                  title       author  year_x  total_weeks  first_week  \
# 0  "H" Is For Homicide  Sue Grafton    1991           15  1991-05-05
# 1  "H" Is For Homicide  Sue Grafton    1991           15  1991-05-05
# 2  "H" Is For Homicide  Sue Grafton    1991           15  1991-05-05
# 3  "H" Is For Homicide  Sue Grafton    1991           15  1991-05-05
# 4  "H" Is For Homicide  Sue Grafton    1991           15  1991-05-05
#
#    debut_rank  best_rank  year_y        week  rank
# 0           1          2    1991  1991-05-05    15
# 1           1          2    1991  1991-05-12     5
# 2           1          2    1991  1991-05-19     2
# 3           1          2    1991  1991-05-26     2
# 4           1          2    1991  1991-06-02     5

# %%
nyt_df.drop_duplicates(inplace=True)

# %%
nyt_df.drop(columns=['year_y'], inplace=True)
nyt_df.rename(columns={'year_x': 'year'}, inplace=True)

# %%
nyt_df.isna().sum()
# Out:
# title           0
# author         10
# year            0
# total_weeks     0
# first_week      0
# debut_rank      0
# best_rank       0
# week            0
# rank            0
# dtype: int64

# %%
nyt_df.shape
# Out:
# (64254, 9)

# %%
df = fuzzy_merge(nyt_df,sale_df,'title','Book_Name',threshold=85)
df.head()
# Out:
#                    title             author  year  total_weeks  first_week  \
# 0  Chasing Harry Winston  Lauren Weisberger  2008           11  2008-06-15
# 1  Chasing Harry Winston  Lauren Weisberger  2008           11  2008-06-15
# 2  Chasing Harry Winston  Lauren Weisberger  2008           11  2008-06-15
# 3  Chasing Harry Winston  Lauren Weisberger  2008           11  2008-06-15
# 4  Chasing Harry Winston  Lauren Weisberger  2008           11  2008-06-15
#
#    debut_rank  best_rank        week  rank              Book_Name  \
# 0           5          4  2008-06-15     6  Chasing Harry Winston
# 1           5          4  2008-06-22     6  Chasing Harry Winston
# 2           5          4  2008-06-29     6  Chasing Harry Winston
# 3           5          4  2008-07-06     4  Chasing Harry Winston
# 4           5          4  2008-07-13     8  Chasing Harry Winston
#
#               Author Author_Rating          Genre  Gross_Sales  \
# 0  Lauren Weisberger        Novice  genre fiction       558.88
# 1  Lauren Weisberger        Novice  genre fiction       558.88
# 2  Lauren Weisberger        Novice  genre fiction       558.88
# 3  Lauren Weisberger        Novice  genre fiction       558.88
# 4  Lauren Weisberger        Novice  genre fiction       558.88
#
#    Publisher_Revenue  Sale_Price  Sales_Rank  Units_Sold
# 0            335.328        4.99        1042        4440
# 1            335.328        4.99        1042        4440
# 2            335.328        4.99        1042        4440
# 3            335.328        4.99        1042        4440
# 4            335.328        4.99        1042        4440

# %%
print(df.shape,'\n')
print(df.columns,'\n')
# Out:
# (5211, 18)
#
# Index(['title', 'author', 'year', 'total_weeks', 'first_week', 'debut_rank',
#        'best_rank', 'week', 'rank', 'Book_Name', 'Author', 'Author_Rating',
#        'Genre', 'Gross_Sales', 'Publisher_Revenue', 'Sale_Price', 'Sales_Rank',
#        'Units_Sold'],
#       dtype='object')

# %%
df.drop(columns=['Book_Name'], inplace=True)
df.rename(columns={'title_left':'title'}, inplace=True)

# %%
df.isna().sum()
# Out:
# title                0
# author               0
# year                 0
# total_weeks          0
# first_week           0
# debut_rank           0
# best_rank            0
# week                 0
# rank                 0
# Author               0
# Author_Rating        0
# Genre                0
# Gross_Sales          0
# Publisher_Revenue    0
# Sale_Price           0
# Sales_Rank           0
# Units_Sold           0
# dtype: int64

# %%
df = fuzzy_merge(df,gr,'title','title',threshold=85)

# %%
print(df.shape,'\n')
print(df.columns,'\n')
# Out:
# (2133244, 28)
#
# Index(['title_left', 'author_left', 'year', 'total_weeks', 'first_week',
#        'debut_rank', 'best_rank', 'week', 'rank', 'Author', 'Author_Rating',
#        'Genre', 'Gross_Sales', 'Publisher_Revenue', 'Sale_Price', 'Sales_Rank',
#        'Units_Sold', 'book_id', 'title_right', 'author_right',
#        'publication_year', 'average_rating', 'ratings_count', 'description',
#        'rating', 'review_text', 'n_votes', 'date_added'],
#       dtype='object')

# %%
df.drop(columns=['title_right', 'author_right','Author','book_id'], inplace=True)
df.rename(columns={'title_left':'title','author_left':'author'}, inplace=True)

# %%
df.isna().sum()
# Out:
# title                0
# author               0
# year                 0
# total_weeks          0
# first_week           0
# debut_rank           0
# best_rank            0
# week                 0
# rank                 0
# Author_Rating        0
# Genre                0
# Gross_Sales          0
# Publisher_Revenue    0
# Sale_Price           0
# Sales_Rank           0
# Units_Sold           0
# publication_year     0
# average_rating       0
# ratings_count        0
# description          0
# rating               0
# review_text          0
# n_votes              0
# date_added           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['title', 'author', 'year', 'total_weeks', 'first_week', 'debut_rank',
#        'best_rank', 'week', 'rank', 'Author_Rating', 'Genre', 'Gross_Sales',
#        'Publisher_Revenue', 'Sale_Price', 'Sales_Rank', 'Units_Sold',
#        'publication_year', 'average_rating', 'ratings_count', 'description',
#        'rating', 'review_text', 'n_votes', 'date_added'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133244 entries, 0 to 2133243
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   title              object
#  1   author             object
#  2   year               int64
#  3   total_weeks        int64
#  4   first_week         object
#  5   debut_rank         int64
#  6   best_rank          int64
#  7   week               object
#  8   rank               int64
#  9   Author_Rating      object
#  10  Genre              object
#  11  Gross_Sales        float64
#  12  Publisher_Revenue  float64
#  13  Sale_Price         float64
#  14  Sales_Rank         int64
#  15  Units_Sold         int64
#  16  publication_year   Int64
#  17  average_rating     float64
#  18  ratings_count      int64
#  19  description        object
#  20  rating             float64
#  21  review_text        object
#  22  n_votes            float64
#  23  date_added         object
# dtypes: Int64(1), float64(6), int64(8), object(9)
# memory usage: 392.6+ MB

# %%
df['first_week'] = pd.to_datetime(df['first_week'], errors='coerce')
df['week'] = pd.to_datetime(df['week'], errors='coerce')
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
# Out:
# /tmp/ipykernel_192846/3608175017.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
# /tmp/ipykernel_192846/3608175017.py:3: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df.head(10)
# Out:
#                    title             author  year  total_weeks first_week  \
# 0  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 1  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 2  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 3  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 4  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 5  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 6  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 7  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 8  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
# 9  Chasing Harry Winston  Lauren Weisberger  2008           11 2008-06-15
#
#    debut_rank  best_rank       week  rank Author_Rating  ... Sales_Rank  \
# 0           5          4 2008-06-15     6        Novice  ...       1042
# 1           5          4 2008-06-15     6        Novice  ...       1042
# 2           5          4 2008-06-15     6        Novice  ...       1042
# 3           5          4 2008-06-15     6        Novice  ...       1042
# 4           5          4 2008-06-15     6        Novice  ...       1042
# 5           5          4 2008-06-15     6        Novice  ...       1042
# 6           5          4 2008-06-15     6        Novice  ...       1042
# 7           5          4 2008-06-15     6        Novice  ...       1042
# 8           5          4 2008-06-15     6        Novice  ...       1042
# 9           5          4 2008-06-15     6        Novice  ...       1042
#
#    Units_Sold  publication_year  average_rating  ratings_count  \
# 0        4440              2008            3.32             56
# 1        4440              2008            3.32             56
# 2        4440              2008            3.32             56
# 3        4440              2008            3.32             56
# 4        4440              2008            3.32             56
# 5        4440              2008            3.32             56
# 6        4440              2008            3.32             64
# 7        4440              2008            3.32             64
# 8        4440              2008            3.32             64
# 9        4440              2008            3.32             64
#
#                                          description  rating  \
# 0  Meet Emmy, Leigh, and Adriana. Best friends si...     5.0
# 1  Meet Emmy, Leigh, and Adriana. Best friends si...     3.0
# 2  Meet Emmy, Leigh, and Adriana. Best friends si...     3.0
# 3  Meet Emmy, Leigh, and Adriana. Best friends si...     3.0
# 4  Meet Emmy, Leigh, and Adriana. Best friends si...     3.0
# 5  Meet Emmy, Leigh, and Adriana. Best friends si...     1.0
# 6  The bestselling author of "The Devil Wears Pra...     5.0
# 7  The bestselling author of "The Devil Wears Pra...     3.0
# 8  The bestselling author of "The Devil Wears Pra...     4.0
# 9  The bestselling author of "The Devil Wears Pra...     0.0
#
#                                          review_text  n_votes  \
# 0  Great easy read! I loved how it referenced pop...      0.0
# 1  Fun read (or rather, listen). I really liked t...      0.0
# 2                                               o.k.      0.0
# 3  Leigh and Emmy were pretty boring all by thems...      0.0
# 4  Better than Everyone Worth Knowing, but still ...      0.0
# 5  I agree with all the other reviewers, this boo...      1.0
# 6  I give this book a 5 star! This is amazing! I ...      0.0
# 7  This is a great 'summer' read book. I thought ...      0.0
# 8  I was looking for something girly, funny and w...      0.0
# 9  i left this book in taiwan... but for some rea...      0.0
#
#                   date_added
# 0  2008-10-11 17:42:40-07:00
# 1  2010-01-26 23:48:19-08:00
# 2  2009-07-21 23:35:10-07:00
# 3  2009-04-15 15:12:10-07:00
# 4  2009-05-18 20:22:57-07:00
# 5  2013-02-24 15:42:58-08:00
# 6  2012-12-30 10:57:14-08:00
# 7  2011-04-25 23:16:05-07:00
# 8  2008-05-07 09:18:53-07:00
# 9  2008-10-02 07:04:43-07:00
#
# [10 rows x 24 columns]

# %%
print(df[(df['Gross_Sales'] - df['Units_Sold'] < 0) & (df['Sale_Price'] > 1)][['title', 'Units_Sold', 'Gross_Sales', 'Sale_Price']])
# Out:
#                          title  Units_Sold  Gross_Sales  Sale_Price
# 0        Chasing Harry Winston        4440       558.88        4.99
# 1        Chasing Harry Winston        4440       558.88        4.99
# 2        Chasing Harry Winston        4440       558.88        4.99
# 3        Chasing Harry Winston        4440       558.88        4.99
# 4        Chasing Harry Winston        4440       558.88        4.99
# ...                        ...         ...          ...         ...
# 2133239        Change Of Heart        3915       990.35        6.83
# 2133240        Change Of Heart        3915       990.35        6.83
# 2133241        Change Of Heart        3915       990.35        6.83
# 2133242        Change Of Heart        3915       990.35        6.83
# 2133243        Change Of Heart        3915       990.35        6.83
#
# [707082 rows x 4 columns]

# %%
df.shape
# Out:
# (2133244, 24)

# %%
df.to_csv(r'/home/check/DATA/university/yr3, hk1/DS102 - ML for Statistic/Đồ án/goodread/DS102/DATA/silver/silver_1.csv', index = False)
